# %%
import pandas as pd




mistral = pd.read_csv("../Data/4_Mistral8GB_2.csv")
print("Mistral prompts:",mistral.shape[0])
print("Mistral r:", mistral["Saved"].corr(mistral["MistralSaved"], method='pearson'))
# Out:
# 774
# Pearson's r: 0.05943152454780361

# %%
# Case 1 corresponds to LeftSide=1
# Case 2 corresponds to LeftSide=0

# %%
df
# Out:
#                    ExtendedSessionID         ResponseID        UserID  \
# 0     -1102906064_5780158015637662.0  xJ9Jtyia3iYpcoXnF  5.780158e+15
# 1     -1102906064_5780158015637662.0  xJ9Jtyia3iYpcoXnF  5.780158e+15
# 2      1389583688_8569199469578563.0  m7ApkzKEJoLKc59Ni  8.569199e+15
# 3      1389583688_8569199469578563.0  m7ApkzKEJoLKc59Ni  8.569199e+15
# 4        40291908_6605769495794762.0  uay2Yp4T4Rn4iCb5T  6.605769e+15
# ...                              ...                ...           ...
# 1995   -434778790_8536024894565344.0  vpRKGqigdnLcsDEHL  8.536025e+15
# 1996   -362490646_7149194821249694.0  Koxi6p7JFHXDgAaPN  7.149195e+15
# 1997   -362490646_7149194821249694.0  Koxi6p7JFHXDgAaPN  7.149195e+15
# 1998   1300407251_8975030210469560.0  xvC3cyyotwYfpMA7C  8.975030e+15
# 1999   1300407251_8975030210469560.0  xvC3cyyotwYfpMA7C  8.975030e+15
#
#                        Timestamp  \
# 0     2024-05-27T23:50:07.516298
# 1     2024-05-27T23:50:07.516298
# ...
